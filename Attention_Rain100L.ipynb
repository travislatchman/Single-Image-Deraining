# %%
import os
import random
import numpy as np
import time
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.transforms import Lambda
from torch.cuda.amp import GradScaler, autocast
from torch.autograd import Variable

from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

import pandas as pd
import matplotlib.pyplot as plt

# %%
print(torch.version.cuda)

print("GPU Available: ", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU is available.")
else:
    print("GPU is not available.")
# Out:
# 11.7
# GPU Available:  True
# GPU is available.

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ##### Construct Rain100L Dataset - Load both Rainy and Norainy images

# %%
# # Set a random seed
# random.seed(42)

# # Shuffle the norain_files and rain_files before splitting
# random.shuffle(norain_files)
# random.shuffle(rain_files)

# data_path = "Rain100L"
# norain_files = sorted(os.listdir(data_path))
# rain_files = sorted(os.listdir(os.path.join(data_path, "rainy")))

# # Split the dataset
# split = (0.7, 0.2, 0.1)
# total = len(norain_files)
# train_idx = int(total * split[0])
# val_idx = int(total * (split[0] + split[1]))

# train_files = norain_files[:train_idx]
# val_files = norain_files[train_idx:val_idx]
# test_files = norain_files[val_idx:]

# # 2. Create the dataset loader for training, validation, and test sets

# class RainDataset(Dataset):
#     def __init__(self, data_path, norain_files, rain_files, transform=None):
#         self.data_path = data_path
#         self.norain_files = norain_files
#         self.rain_files = rain_files
#         self.transform = transform

#     def __len__(self):
#         return len(self.norain_files)

#     def __getitem__(self, idx):
#         norain_img = Image.open(os.path.join(self.data_path, self.norain_files[idx]))
#         rain_img = Image.open(os.path.join(self.data_path, "rainy", self.rain_files[idx]))

#         if self.transform:
#             norain_img = self.transform(norain_img)
#             rain_img = self.transform(rain_img)

#         return rain_img, norain_img

# transform = transforms.Compose([transforms.ToTensor()])

# train_dataset = RainDataset(data_path, train_files, rain_files[:train_idx], transform)
# val_dataset = RainDataset(data_path, val_files, rain_files[train_idx:val_idx], transform)
# test_dataset = RainDataset(data_path, test_files, rain_files[val_idx:], transform)

# train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
class Rain100L_Dataset(Dataset):
    def __init__(self, rainy_path, norainy_path, data, transform=None):
        self.rainy_path = rainy_path
        self.norainy_path = norainy_path
        self.data = data
        self.transform = transform
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        rainy_img_name, norainy_img_name = self.data[idx]
        rainy_image = Image.open(os.path.join(self.rainy_path, rainy_img_name))
        norainy_image = Image.open(os.path.join(self.norainy_path, norainy_img_name))

        if self.transform:
            rainy_image = self.transform(rainy_image)
            norainy_image = self.transform(norainy_image)

        return rainy_image, norainy_image

# %% [markdown]
# ##### First implementation idea for splitting

# %%
def split_data(rainy_path, norainy_path, train_ratio=0.7, val_ratio=0.2, test_ratio=0.1):
    # Set a random seed
    random.seed(42)

    rainy_files = sorted(os.listdir(rainy_path))
    norainy_files = sorted(os.listdir(norainy_path))
    
    data_size = len(rainy_files)
    indices = list(range(data_size))
    random.shuffle(indices)

    train_indices = indices[:int(data_size * train_ratio)]
    val_indices = indices[int(data_size * train_ratio):int(data_size * (train_ratio + val_ratio))]
    test_indices = indices[int(data_size * (train_ratio + val_ratio)):]

    train_data = [(rainy_files[i], norainy_files[i]) for i in train_indices]
    val_data = [(rainy_files[i], norainy_files[i]) for i in val_indices]
    test_data = [(rainy_files[i], norainy_files[i]) for i in test_indices]

    return train_data, val_data, test_data

# %% [markdown]
# ### Split the data and create data loaders

# %%
def resize_and_pad(target_width, target_height):
    def _resize_and_pad(image):
        aspect_ratio = image.width / image.height
        if aspect_ratio > 1:  # width > height
            new_width = target_width
            new_height = int(new_width / aspect_ratio)
        else:  # height >= width
            new_height = target_height
            new_width = int(new_height * aspect_ratio)

        resized_image = image.resize((new_width, new_height), Image.BICUBIC)

        padded_image = Image.new('RGB', (target_width, target_height), color=0)
        left_padding = (target_width - new_width) // 2
        top_padding = (target_height - new_height) // 2
        padded_image.paste(resized_image, (left_padding, top_padding))
        return padded_image

    return _resize_and_pad

# %%
rainy_path = r"G:\\My Drive\Deraining\\Rain100L\\rainy"
norainy_path = r"G:\\My Drive\\Deraining\\Rain100L"


train_data, val_data, test_data = split_data(rainy_path, norainy_path)

target_width = 480
target_height = 320
transform = transforms.Compose([
    Lambda(resize_and_pad(target_width, target_height)),
    transforms.ToTensor()
])

train_set = Rain100L_Dataset(rainy_path, norainy_path, train_data, transform)
val_set = Rain100L_Dataset(rainy_path, norainy_path, val_data, transform)
test_set = Rain100L_Dataset(rainy_path, norainy_path, test_data, transform)

train_loader = DataLoader(train_set, batch_size=4, shuffle=True)
val_loader = DataLoader(val_set, batch_size=4, shuffle=False)
test_loader = DataLoader(test_set, batch_size=4, shuffle=False)

# %%
# train_loader = DataLoader(train_set, batch_size=4, shuffle=True, num_workers=2)
# val_loader = DataLoader(val_set, batch_size=4, shuffle=False, num_workers=2)
# test_loader = DataLoader(test_set, batch_size=4, shuffle=False, num_workers=2)



# train_loader = DataLoader(train_set, batch_size=16, shuffle=True, num_workers=0)
# val_loader = DataLoader(val_set, batch_size=16, shuffle=False, num_workers=0)
# test_loader = DataLoader(test_set, batch_size=1, shuffle=False, num_workers=0)

# %% [markdown]
# ### Attention U-Net Implementation

# %%
class LocalAttention(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super(LocalAttention, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        q = self.conv(x)
        k = self.conv(x)
        v = self.conv(x)

        attn_weights = torch.matmul(q, k.transpose(2, 3))
        attn_weights = self.softmax(attn_weights)

        attn_output = torch.matmul(attn_weights, v)
        return attn_output


class UNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet, self).__init__()

        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True)
            )

        def up_block(in_channels, out_channels):
            return nn.Sequential(
                nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2),
                nn.ReLU(inplace=True)
            )

        self.enc1 = conv_block(in_channels, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)

        self.pool = nn.MaxPool2d(2)

        self.middle = conv_block(512, 1024)

        self.up4 = up_block(1024, 512)
        self.dec4 = conv_block(1024, 512)
        self.up3 = up_block(512, 256)
        self.dec3 = conv_block(512, 256)
        self.up2 = up_block(256, 128)
        self.dec2 = conv_block(256, 128)

        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = conv_block(128, 64)

        self.output = nn.Conv2d(64, out_channels, kernel_size=1)

        # Add a local attention layer
        self.local_attention = LocalAttention(256, 256)

    def forward(self, x):
        enc1 = self.enc1(x)
        enc2 = self.enc2(self.pool(enc1))
        enc3 = self.enc3(self.pool(enc2))
        enc4 = self.enc4(self.pool(enc3))

        middle = self.middle(self.pool(enc4))

        up4 = self.up4(middle)
        merge4 = torch.cat([enc4, up4], dim=1)
        dec4 = self.dec4(merge4)

        up3 = self.up3(dec4)
        merge3 = torch.cat([enc3, up3], dim=1)
        dec3 = self.dec3(merge3)

        # Apply the local attention layer
        dec3 = self.local_attention(dec3)

        up2 = self.up2(dec3)
        merge2 = torch.cat([enc2, up2], dim=1)
        dec2 = self.dec2(merge2)

        up1 = self.up1(dec2)
        merge1 = torch.cat([enc1, up1], dim=1)
        dec1 = self.dec1(merge1)

        output = self.output(dec1)
        return output


unet = UNet(3, 3)  # Adjust input and output channels to 3 for RGB images

# %%
# rainy_path = 'Rain100L/rainy'
# norainy_path = 'Rain100L'

# %%
# # Set the device index to the desired GPU (0 for the first GPU, 1 for the second, etc.)
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# # Now you can move your model and data to the selected device
# model = unet.to(device)
# data = unet.to(device)

# %% [markdown]
# ##### To train, validate, and test the U-Net model on the Rain100L dataset
# 1. Prepare the dataset and split it into training, validation, and test sets.
# 2. Create the dataset loader for training, validation, and test sets.
# 3. Train the model on the training set and validate on the validation set.
# 4. Test the model on the test set, compute the evaluation metrics (PSNR and SSIM), and save the derained images.

# %% [markdown]
# ### training loop with gradient clipping applied to the scaled gradients

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
unet = UNet(3, 3).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(unet.parameters(), lr=0.001)

num_epochs = 200

# Initialize gradient scaler for mixed-precision training
scaler = GradScaler()
accumulation_steps = 4

# Initialize lists to store train and validation losses
train_losses = []
val_losses = []

clip_value = 1.0  # Adjust this value as needed

print('--- Training starts! ---')
start_time_train = time.time()

for epoch in range(num_epochs):
    unet.train()
    train_loss = 0.0

    start_time_train_epoch = time.time()
    
    optimizer.zero_grad()
    
    for step, (rain, norain) in enumerate(train_loader):
        rain = rain.to(device)
        norain = norain.to(device)

        # Use autocast for mixed-precision training
        with autocast():
            output = unet(rain)
            loss = criterion(output, norain)
        
        # Scale the loss and backpropagate
        scaler.scale(loss).backward()

        # Apply gradient clipping to the scaled gradients
        if clip_value is not None:
            torch.nn.utils.clip_grad_norm_(unet.parameters(), clip_value, norm_type=2)
        
        if (step + 1) % accumulation_steps == 0:
            # Update the model weights and optimizer state
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
        
        train_loss += loss.item()
    
    # Calculate the average loss for the epoch and append it to the list
    train_losses.append(train_loss/len(train_loader))

    end_time_train_epoch = time.time() - start_time_train_epoch
    
    unet.eval()
    val_loss = 0.0
    
    start_time_val_epoch = time.time()

    with torch.no_grad():
        for rain, norain in val_loader:
            rain = rain.to(device)
            norain = norain.to(device)

            with autocast():
                output = unet(rain)
                loss = criterion(output, norain)

            val_loss += loss.item()

    val_losses.append(val_loss/len(val_loader))
    end_time_val_epoch = time.time() - start_time_val_epoch

    print(f"Epoch {epoch+1}/{num_epochs} - Train loss: {train_losses[-1]:.6f}, Val loss: {val_losses[-1]:.6f}")
    print(f"Epoch {epoch+1} - Training time: {end_time_train_epoch:.4f} seconds, Validation time: {end_time_val_epoch:.4f} seconds")

end_time_train = time.time() - start_time_train
print('Training time: {0:.4f} seconds'.format(end_time_train))
# Out:
# --- Training starts! ---
# Epoch 1/200 - Train loss: 0.140475, Val loss: 0.081089
# Epoch 1 - Training time: 7.8090 seconds, Validation time: 0.8562 seconds
# Epoch 2/200 - Train loss: 0.053107, Val loss: 0.082788
# Epoch 2 - Training time: 4.8709 seconds, Validation time: 0.8415 seconds
# Epoch 3/200 - Train loss: 0.061826, Val loss: 0.024708
# Epoch 3 - Training time: 4.8897 seconds, Validation time: 0.8364 seconds
# Epoch 4/200 - Train loss: 0.027165, Val loss: 0.026631
# Epoch 4 - Training time: 4.9110 seconds, Validation time: 0.8381 seconds
# Epoch 5/200 - Train loss: 0.020068, Val loss: 0.018720
# Epoch 5 - Training time: 4.9208 seconds, Validation time: 0.8457 seconds
# Epoch 6/200 - Train loss: 0.013717, Val loss: 0.012405
# Epoch 6 - Training time: 4.9944 seconds, Validation time: 0.8524 seconds
# Epoch 7/200 - Train loss: 0.011790, Val loss: 0.011655
# Epoch 7 - Training time: 4.9738 seconds, Validation time: 0.8533 seconds
# Epoch 8/200 - Train loss: 0.011024, Val loss: 0.011680
# Epoch 8 - Training time: 4.9615 seconds, Validation time: 0.8526 seconds
# Epoch 9/200 - Train loss: 0.010077, Val loss: 0.010110
# Epoch 9 - Training time: 4.9441 seconds, Validation time: 0.8562 seconds
# Epoch 10/200 - Train loss: 0.010161, Val loss: 0.010496
# Epoch 10 - Training time: 4.9761 seconds, Validation time: 0.8512 seconds
# Epoch 11/200 - Train loss: 0.009585, Val loss: 0.010328
# Epoch 11 - Training time: 4.9783 seconds, Validation time: 0.8512 seconds
# Epoch 12/200 - Train loss: 0.009574, Val loss: 0.011098
# Epoch 12 - Training time: 4.9528 seconds, Validation time: 0.8562 seconds
# Epoch 13/200 - Train loss: 0.009560, Val loss: 0.008724
# Epoch 13 - Training time: 4.9829 seconds, Validation time: 0.8562 seconds
# Epoch 14/200 - Train loss: 0.007844, Val loss: 0.007490
# Epoch 14 - Training time: 5.0217 seconds, Validation time: 0.8516 seconds
# Epoch 15/200 - Train loss: 0.006578, Val loss: 0.007053
# Epoch 15 - Training time: 4.9693 seconds, Validation time: 0.8540 seconds
# Epoch 16/200 - Train loss: 0.005668, Val loss: 0.006453
# Epoch 16 - Training time: 4.9507 seconds, Validation time: 0.8508 seconds
# Epoch 17/200 - Train loss: 0.005411, Val loss: 0.006916
# Epoch 17 - Training time: 4.9826 seconds, Validation time: 0.8442 seconds
# Epoch 18/200 - Train loss: 0.005676, Val loss: 0.006955
# Epoch 18 - Training time: 4.9475 seconds, Validation time: 0.8452 seconds
# Epoch 19/200 - Train loss: 0.005966, Val loss: 0.006075
# Epoch 19 - Training time: 4.9481 seconds, Validation time: 0.8439 seconds
# Epoch 20/200 - Train loss: 0.006129, Val loss: 0.006353
# Epoch 20 - Training time: 4.9460 seconds, Validation time: 0.8432 seconds
# Epoch 21/200 - Train loss: 0.005399, Val loss: 0.005510
# Epoch 21 - Training time: 4.9551 seconds, Validation time: 0.8522 seconds
# Epoch 22/200 - Train loss: 0.005197, Val loss: 0.006188
# Epoch 22 - Training time: 4.9520 seconds, Validation time: 0.8503 seconds
# Epoch 23/200 - Train loss: 0.005100, Val loss: 0.006371
# Epoch 23 - Training time: 4.9431 seconds, Validation time: 0.8504 seconds
# Epoch 24/200 - Train loss: 0.005386, Val loss: 0.006855
# Epoch 24 - Training time: 4.9856 seconds, Validation time: 0.8452 seconds
# Epoch 25/200 - Train loss: 0.006168, Val loss: 0.005723
# Epoch 25 - Training time: 4.9424 seconds, Validation time: 0.8432 seconds
# Epoch 26/200 - Train loss: 0.005526, Val loss: 0.005202
# Epoch 26 - Training time: 4.9742 seconds, Validation time: 0.8531 seconds
# Epoch 27/200 - Train loss: 0.006028, Val loss: 0.006387
# Epoch 27 - Training time: 4.9851 seconds, Validation time: 0.8532 seconds
# Epoch 28/200 - Train loss: 0.005365, Val loss: 0.007097
# Epoch 28 - Training time: 4.9813 seconds, Validation time: 0.8537 seconds
# Epoch 29/200 - Train loss: 0.005464, Val loss: 0.006045
# Epoch 29 - Training time: 4.9761 seconds, Validation time: 0.8580 seconds
# Epoch 30/200 - Train loss: 0.004837, Val loss: 0.005522
# Epoch 30 - Training time: 4.9779 seconds, Validation time: 0.8562 seconds
# Epoch 31/200 - Train loss: 0.004892, Val loss: 0.006181
# Epoch 31 - Training time: 4.9768 seconds, Validation time: 0.8516 seconds
# Epoch 32/200 - Train loss: 0.004766, Val loss: 0.005760
# Epoch 32 - Training time: 4.9808 seconds, Validation time: 0.8510 seconds
# Epoch 33/200 - Train loss: 0.004488, Val loss: 0.005132
# Epoch 33 - Training time: 4.9742 seconds, Validation time: 0.8556 seconds
# Epoch 34/200 - Train loss: 0.004139, Val loss: 0.004909
# Epoch 34 - Training time: 4.9584 seconds, Validation time: 0.8522 seconds
# Epoch 35/200 - Train loss: 0.004010, Val loss: 0.004536
# Epoch 35 - Training time: 4.9845 seconds, Validation time: 0.8503 seconds
# Epoch 36/200 - Train loss: 0.004553, Val loss: 0.006016
# Epoch 36 - Training time: 4.9685 seconds, Validation time: 0.8552 seconds
# Epoch 37/200 - Train loss: 0.004344, Val loss: 0.005347
# Epoch 37 - Training time: 4.9798 seconds, Validation time: 0.8535 seconds
# Epoch 38/200 - Train loss: 0.004500, Val loss: 0.005405
# Epoch 38 - Training time: 4.9705 seconds, Validation time: 0.8532 seconds
# Epoch 39/200 - Train loss: 0.004319, Val loss: 0.004525
# Epoch 39 - Training time: 5.0072 seconds, Validation time: 0.8503 seconds
# Epoch 40/200 - Train loss: 0.004001, Val loss: 0.004858
# Epoch 40 - Training time: 4.9695 seconds, Validation time: 0.8545 seconds
# Epoch 41/200 - Train loss: 0.004054, Val loss: 0.004403
# Epoch 41 - Training time: 5.0321 seconds, Validation time: 0.8570 seconds
# Epoch 42/200 - Train loss: 0.003509, Val loss: 0.004102
# Epoch 42 - Training time: 4.9724 seconds, Validation time: 0.8545 seconds
# Epoch 43/200 - Train loss: 0.003568, Val loss: 0.004801
# Epoch 43 - Training time: 5.0063 seconds, Validation time: 0.8558 seconds
# Epoch 44/200 - Train loss: 0.003598, Val loss: 0.004190
# Epoch 44 - Training time: 5.0497 seconds, Validation time: 0.8782 seconds
# Epoch 45/200 - Train loss: 0.003409, Val loss: 0.004027
# Epoch 45 - Training time: 4.9887 seconds, Validation time: 0.8522 seconds
# Epoch 46/200 - Train loss: 0.003585, Val loss: 0.004160
# Epoch 46 - Training time: 4.9683 seconds, Validation time: 0.8526 seconds
# Epoch 47/200 - Train loss: 0.003411, Val loss: 0.004070
# Epoch 47 - Training time: 4.9967 seconds, Validation time: 0.8495 seconds
# Epoch 48/200 - Train loss: 0.003144, Val loss: 0.003759
# Epoch 48 - Training time: 4.9438 seconds, Validation time: 0.8482 seconds
# Epoch 49/200 - Train loss: 0.003545, Val loss: 0.004023
# Epoch 49 - Training time: 4.9616 seconds, Validation time: 0.8570 seconds
# Epoch 50/200 - Train loss: 0.003252, Val loss: 0.003851
# Epoch 50 - Training time: 4.9655 seconds, Validation time: 0.8532 seconds
# Epoch 51/200 - Train loss: 0.003222, Val loss: 0.003404
# Epoch 51 - Training time: 4.9872 seconds, Validation time: 0.8452 seconds
# Epoch 52/200 - Train loss: 0.003048, Val loss: 0.003475
# Epoch 52 - Training time: 5.0005 seconds, Validation time: 0.8452 seconds
# Epoch 53/200 - Train loss: 0.003072, Val loss: 0.003549
# Epoch 53 - Training time: 4.9701 seconds, Validation time: 0.8506 seconds
# Epoch 54/200 - Train loss: 0.002778, Val loss: 0.003845
# Epoch 54 - Training time: 4.9947 seconds, Validation time: 0.8532 seconds
# Epoch 55/200 - Train loss: 0.003185, Val loss: 0.003845
# Epoch 55 - Training time: 4.9618 seconds, Validation time: 0.8492 seconds
# Epoch 56/200 - Train loss: 0.002989, Val loss: 0.003242
# Epoch 56 - Training time: 4.9675 seconds, Validation time: 0.8472 seconds
# Epoch 57/200 - Train loss: 0.003151, Val loss: 0.003668
# Epoch 57 - Training time: 5.0154 seconds, Validation time: 0.8521 seconds
# Epoch 58/200 - Train loss: 0.002877, Val loss: 0.003281
# Epoch 58 - Training time: 5.0001 seconds, Validation time: 0.8462 seconds
# Epoch 59/200 - Train loss: 0.002759, Val loss: 0.003225
# Epoch 59 - Training time: 4.9788 seconds, Validation time: 0.8526 seconds
# Epoch 60/200 - Train loss: 0.003048, Val loss: 0.004393
# Epoch 60 - Training time: 4.9795 seconds, Validation time: 0.8622 seconds
# Epoch 61/200 - Train loss: 0.003535, Val loss: 0.003243
# Epoch 61 - Training time: 4.9989 seconds, Validation time: 0.8523 seconds
# Epoch 62/200 - Train loss: 0.003025, Val loss: 0.003341
# Epoch 62 - Training time: 4.9763 seconds, Validation time: 0.8503 seconds
# Epoch 63/200 - Train loss: 0.002973, Val loss: 0.003370
# Epoch 63 - Training time: 4.9837 seconds, Validation time: 0.8530 seconds
# Epoch 64/200 - Train loss: 0.003353, Val loss: 0.004106
# Epoch 64 - Training time: 5.0077 seconds, Validation time: 0.8512 seconds
# Epoch 65/200 - Train loss: 0.003541, Val loss: 0.005288
# Epoch 65 - Training time: 4.9556 seconds, Validation time: 0.8505 seconds
# Epoch 66/200 - Train loss: 0.003650, Val loss: 0.004355
# Epoch 66 - Training time: 5.0047 seconds, Validation time: 0.8552 seconds
# Epoch 67/200 - Train loss: 0.002860, Val loss: 0.003076
# Epoch 67 - Training time: 4.9927 seconds, Validation time: 0.8502 seconds
# Epoch 68/200 - Train loss: 0.002772, Val loss: 0.003426
# Epoch 68 - Training time: 5.0080 seconds, Validation time: 0.8543 seconds
# Epoch 69/200 - Train loss: 0.002655, Val loss: 0.003513
# Epoch 69 - Training time: 5.0153 seconds, Validation time: 0.8602 seconds
# Epoch 70/200 - Train loss: 0.002988, Val loss: 0.003281
# Epoch 70 - Training time: 5.0150 seconds, Validation time: 0.8635 seconds
# Epoch 71/200 - Train loss: 0.002700, Val loss: 0.003192
# Epoch 71 - Training time: 5.0017 seconds, Validation time: 0.8532 seconds
# Epoch 72/200 - Train loss: 0.002565, Val loss: 0.003007
# Epoch 72 - Training time: 4.9929 seconds, Validation time: 0.8781 seconds
# Epoch 73/200 - Train loss: 0.002750, Val loss: 0.002988
# Epoch 73 - Training time: 4.9805 seconds, Validation time: 0.8482 seconds
# Epoch 74/200 - Train loss: 0.002609, Val loss: 0.003211
# Epoch 74 - Training time: 4.9995 seconds, Validation time: 0.8509 seconds
# Epoch 75/200 - Train loss: 0.002636, Val loss: 0.003397
# Epoch 75 - Training time: 4.9717 seconds, Validation time: 0.8639 seconds
# Epoch 76/200 - Train loss: 0.002675, Val loss: 0.003258
# Epoch 76 - Training time: 6.2343 seconds, Validation time: 0.8784 seconds
# Epoch 77/200 - Train loss: 0.002504, Val loss: 0.003083
# Epoch 77 - Training time: 5.1447 seconds, Validation time: 0.8612 seconds
# Epoch 78/200 - Train loss: 0.002739, Val loss: 0.003302
# Epoch 78 - Training time: 5.0093 seconds, Validation time: 0.8601 seconds
# Epoch 79/200 - Train loss: 0.002411, Val loss: 0.002744
# Epoch 79 - Training time: 4.9575 seconds, Validation time: 0.8452 seconds
# Epoch 80/200 - Train loss: 0.002374, Val loss: 0.002930
# Epoch 80 - Training time: 4.9811 seconds, Validation time: 0.8553 seconds
# Epoch 81/200 - Train loss: 0.002431, Val loss: 0.003101
# Epoch 81 - Training time: 4.9735 seconds, Validation time: 0.8572 seconds
# Epoch 82/200 - Train loss: 0.002634, Val loss: 0.003487
# Epoch 82 - Training time: 4.9652 seconds, Validation time: 0.8423 seconds
# Epoch 83/200 - Train loss: 0.003646, Val loss: 0.008155
# Epoch 83 - Training time: 4.9769 seconds, Validation time: 0.8477 seconds
# Epoch 84/200 - Train loss: 0.004828, Val loss: 0.005705
# Epoch 84 - Training time: 4.9806 seconds, Validation time: 0.8452 seconds
# Epoch 85/200 - Train loss: 0.004236, Val loss: 0.005284
# Epoch 85 - Training time: 4.9489 seconds, Validation time: 0.8502 seconds
# Epoch 86/200 - Train loss: 0.003270, Val loss: 0.003395
# Epoch 86 - Training time: 4.9931 seconds, Validation time: 0.8485 seconds
# Epoch 87/200 - Train loss: 0.002583, Val loss: 0.002836
# Epoch 87 - Training time: 4.9448 seconds, Validation time: 0.8462 seconds
# Epoch 88/200 - Train loss: 0.002241, Val loss: 0.002681
# Epoch 88 - Training time: 4.9397 seconds, Validation time: 0.8462 seconds
# Epoch 89/200 - Train loss: 0.002326, Val loss: 0.002989
# Epoch 89 - Training time: 4.9895 seconds, Validation time: 0.8473 seconds
# Epoch 90/200 - Train loss: 0.002271, Val loss: 0.002689
# Epoch 90 - Training time: 4.9774 seconds, Validation time: 0.8504 seconds
# Epoch 91/200 - Train loss: 0.002314, Val loss: 0.003097
# Epoch 91 - Training time: 4.9613 seconds, Validation time: 0.8540 seconds
# Epoch 92/200 - Train loss: 0.002388, Val loss: 0.003584
# Epoch 92 - Training time: 4.9976 seconds, Validation time: 0.8482 seconds
# Epoch 93/200 - Train loss: 0.002675, Val loss: 0.002869
# Epoch 93 - Training time: 4.9339 seconds, Validation time: 0.8532 seconds
# Epoch 94/200 - Train loss: 0.002343, Val loss: 0.002649
# Epoch 94 - Training time: 4.9884 seconds, Validation time: 0.8462 seconds
# Epoch 95/200 - Train loss: 0.002317, Val loss: 0.003119
# Epoch 95 - Training time: 5.0045 seconds, Validation time: 0.8507 seconds
# Epoch 96/200 - Train loss: 0.002816, Val loss: 0.003232
# Epoch 96 - Training time: 4.9520 seconds, Validation time: 0.8454 seconds
# Epoch 97/200 - Train loss: 0.002808, Val loss: 0.002983
# Epoch 97 - Training time: 4.9810 seconds, Validation time: 0.8441 seconds
# Epoch 98/200 - Train loss: 0.002630, Val loss: 0.003312
# Epoch 98 - Training time: 4.9795 seconds, Validation time: 0.8518 seconds
# Epoch 99/200 - Train loss: 0.002738, Val loss: 0.003223
# Epoch 99 - Training time: 4.9415 seconds, Validation time: 0.8522 seconds
# Epoch 100/200 - Train loss: 0.002842, Val loss: 0.002963
# Epoch 100 - Training time: 4.9572 seconds, Validation time: 0.8502 seconds
# Epoch 101/200 - Train loss: 0.002601, Val loss: 0.003145
# Epoch 101 - Training time: 4.9792 seconds, Validation time: 0.8542 seconds
# Epoch 102/200 - Train loss: 0.002283, Val loss: 0.002476
# Epoch 102 - Training time: 4.9742 seconds, Validation time: 0.8504 seconds
# Epoch 103/200 - Train loss: 0.002507, Val loss: 0.002870
# Epoch 103 - Training time: 4.9971 seconds, Validation time: 0.8467 seconds
# Epoch 104/200 - Train loss: 0.002435, Val loss: 0.002510
# Epoch 104 - Training time: 4.9592 seconds, Validation time: 0.8462 seconds
# Epoch 105/200 - Train loss: 0.002769, Val loss: 0.003128
# Epoch 105 - Training time: 4.9857 seconds, Validation time: 0.8492 seconds
# Epoch 106/200 - Train loss: 0.002877, Val loss: 0.003994
# Epoch 106 - Training time: 5.0045 seconds, Validation time: 0.8503 seconds
# Epoch 107/200 - Train loss: 0.002558, Val loss: 0.002653
# Epoch 107 - Training time: 4.9927 seconds, Validation time: 0.8524 seconds
# Epoch 108/200 - Train loss: 0.002206, Val loss: 0.003226
# Epoch 108 - Training time: 5.0118 seconds, Validation time: 0.9062 seconds
# Epoch 109/200 - Train loss: 0.002734, Val loss: 0.003740
# Epoch 109 - Training time: 5.0088 seconds, Validation time: 0.8688 seconds
# Epoch 110/200 - Train loss: 0.002949, Val loss: 0.002849
# Epoch 110 - Training time: 5.0257 seconds, Validation time: 0.8554 seconds
# Epoch 111/200 - Train loss: 0.002398, Val loss: 0.002791
# Epoch 111 - Training time: 4.9638 seconds, Validation time: 0.8617 seconds
# Epoch 112/200 - Train loss: 0.002361, Val loss: 0.003043
# Epoch 112 - Training time: 5.0489 seconds, Validation time: 0.8590 seconds
# Epoch 113/200 - Train loss: 0.002528, Val loss: 0.002811
# Epoch 113 - Training time: 5.0502 seconds, Validation time: 0.8662 seconds
# Epoch 114/200 - Train loss: 0.002629, Val loss: 0.002767
# Epoch 114 - Training time: 5.0185 seconds, Validation time: 0.8662 seconds
# Epoch 115/200 - Train loss: 0.002379, Val loss: 0.003464
# Epoch 115 - Training time: 5.0324 seconds, Validation time: 0.8581 seconds
# Epoch 116/200 - Train loss: 0.002512, Val loss: 0.002536
# Epoch 116 - Training time: 4.9919 seconds, Validation time: 0.8488 seconds
# Epoch 117/200 - Train loss: 0.002594, Val loss: 0.002447
# Epoch 117 - Training time: 4.9650 seconds, Validation time: 0.8554 seconds
# Epoch 118/200 - Train loss: 0.002117, Val loss: 0.003369
# Epoch 118 - Training time: 5.0171 seconds, Validation time: 0.8495 seconds
# Epoch 119/200 - Train loss: 0.002356, Val loss: 0.002561
# Epoch 119 - Training time: 5.0017 seconds, Validation time: 0.8512 seconds
# Epoch 120/200 - Train loss: 0.002257, Val loss: 0.002802
# Epoch 120 - Training time: 4.9916 seconds, Validation time: 0.8526 seconds
# Epoch 121/200 - Train loss: 0.002080, Val loss: 0.002282
# Epoch 121 - Training time: 5.0001 seconds, Validation time: 0.8545 seconds
# Epoch 122/200 - Train loss: 0.001872, Val loss: 0.002804
# Epoch 122 - Training time: 4.9965 seconds, Validation time: 0.8474 seconds
# Epoch 123/200 - Train loss: 0.002482, Val loss: 0.003967
# Epoch 123 - Training time: 4.9826 seconds, Validation time: 0.8512 seconds
# Epoch 124/200 - Train loss: 0.003262, Val loss: 0.005481
# Epoch 124 - Training time: 4.9648 seconds, Validation time: 0.8502 seconds
# Epoch 125/200 - Train loss: 0.003597, Val loss: 0.003291
# Epoch 125 - Training time: 4.9719 seconds, Validation time: 0.8547 seconds
# Epoch 126/200 - Train loss: 0.002811, Val loss: 0.002995
# Epoch 126 - Training time: 4.9745 seconds, Validation time: 0.8565 seconds
# Epoch 127/200 - Train loss: 0.002359, Val loss: 0.003128
# Epoch 127 - Training time: 5.0173 seconds, Validation time: 0.8568 seconds
# Epoch 128/200 - Train loss: 0.002486, Val loss: 0.002920
# Epoch 128 - Training time: 4.9705 seconds, Validation time: 0.8564 seconds
# Epoch 129/200 - Train loss: 0.002236, Val loss: 0.002510
# Epoch 129 - Training time: 4.9831 seconds, Validation time: 0.8564 seconds
# Epoch 130/200 - Train loss: 0.002267, Val loss: 0.004048
# Epoch 130 - Training time: 4.9561 seconds, Validation time: 0.8597 seconds
# Epoch 131/200 - Train loss: 0.002555, Val loss: 0.002583
# Epoch 131 - Training time: 5.0014 seconds, Validation time: 0.8494 seconds
# Epoch 132/200 - Train loss: 0.001966, Val loss: 0.003402
# Epoch 132 - Training time: 5.0052 seconds, Validation time: 0.8548 seconds
# Epoch 133/200 - Train loss: 0.002939, Val loss: 0.003580
# Epoch 133 - Training time: 4.9706 seconds, Validation time: 0.8504 seconds
# Epoch 134/200 - Train loss: 0.002886, Val loss: 0.002695
# Epoch 134 - Training time: 5.0063 seconds, Validation time: 0.8476 seconds
# Epoch 135/200 - Train loss: 0.002330, Val loss: 0.002857
# Epoch 135 - Training time: 4.9867 seconds, Validation time: 0.8537 seconds
# Epoch 136/200 - Train loss: 0.002527, Val loss: 0.002803
# Epoch 136 - Training time: 4.9991 seconds, Validation time: 0.8502 seconds
# Epoch 137/200 - Train loss: 0.002135, Val loss: 0.002918
# Epoch 137 - Training time: 4.9565 seconds, Validation time: 0.8444 seconds
# Epoch 138/200 - Train loss: 0.002419, Val loss: 0.004681
# Epoch 138 - Training time: 4.9835 seconds, Validation time: 0.8545 seconds
# Epoch 139/200 - Train loss: 0.003270, Val loss: 0.003535
# Epoch 139 - Training time: 5.0156 seconds, Validation time: 0.8573 seconds
# Epoch 140/200 - Train loss: 0.003283, Val loss: 0.003016
# Epoch 140 - Training time: 5.0061 seconds, Validation time: 0.8601 seconds
# Epoch 141/200 - Train loss: 0.002620, Val loss: 0.003432
# Epoch 141 - Training time: 4.9772 seconds, Validation time: 0.8515 seconds
# Epoch 142/200 - Train loss: 0.002381, Val loss: 0.002659
# Epoch 142 - Training time: 4.9851 seconds, Validation time: 0.8488 seconds
# Epoch 143/200 - Train loss: 0.002279, Val loss: 0.002339
# Epoch 143 - Training time: 4.9774 seconds, Validation time: 0.8512 seconds
# Epoch 144/200 - Train loss: 0.001820, Val loss: 0.002332
# Epoch 144 - Training time: 4.9743 seconds, Validation time: 0.8482 seconds
# Epoch 145/200 - Train loss: 0.002200, Val loss: 0.003075
# Epoch 145 - Training time: 4.9799 seconds, Validation time: 0.8616 seconds
# Epoch 146/200 - Train loss: 0.002941, Val loss: 0.003503
# Epoch 146 - Training time: 4.9697 seconds, Validation time: 0.8515 seconds
# Epoch 147/200 - Train loss: 0.002795, Val loss: 0.003132
# Epoch 147 - Training time: 4.9847 seconds, Validation time: 0.8520 seconds
# Epoch 148/200 - Train loss: 0.002299, Val loss: 0.002920
# Epoch 148 - Training time: 4.9918 seconds, Validation time: 0.8483 seconds
# Epoch 149/200 - Train loss: 0.002170, Val loss: 0.002429
# Epoch 149 - Training time: 5.0044 seconds, Validation time: 0.8486 seconds
# Epoch 150/200 - Train loss: 0.002255, Val loss: 0.002503
# Epoch 150 - Training time: 4.9469 seconds, Validation time: 0.8515 seconds
# Epoch 151/200 - Train loss: 0.002063, Val loss: 0.002511
# Epoch 151 - Training time: 4.9473 seconds, Validation time: 0.8526 seconds
# Epoch 152/200 - Train loss: 0.001955, Val loss: 0.002224
# Epoch 152 - Training time: 4.9621 seconds, Validation time: 0.8617 seconds
# Epoch 153/200 - Train loss: 0.001724, Val loss: 0.002290
# Epoch 153 - Training time: 4.9775 seconds, Validation time: 0.8517 seconds
# Epoch 154/200 - Train loss: 0.002091, Val loss: 0.003050
# Epoch 154 - Training time: 4.9788 seconds, Validation time: 0.8472 seconds
# Epoch 155/200 - Train loss: 0.002160, Val loss: 0.002277
# Epoch 155 - Training time: 4.9738 seconds, Validation time: 0.8542 seconds
# Epoch 156/200 - Train loss: 0.001824, Val loss: 0.002189
# Epoch 156 - Training time: 4.9806 seconds, Validation time: 0.8545 seconds
# Epoch 157/200 - Train loss: 0.001968, Val loss: 0.003415
# Epoch 157 - Training time: 5.0086 seconds, Validation time: 0.8532 seconds
# Epoch 158/200 - Train loss: 0.002860, Val loss: 0.003194
# Epoch 158 - Training time: 4.9778 seconds, Validation time: 0.8464 seconds
# Epoch 159/200 - Train loss: 0.002260, Val loss: 0.002294
# Epoch 159 - Training time: 4.9635 seconds, Validation time: 0.8474 seconds
# Epoch 160/200 - Train loss: 0.001855, Val loss: 0.002497
# Epoch 160 - Training time: 4.9883 seconds, Validation time: 0.8482 seconds
# Epoch 161/200 - Train loss: 0.001796, Val loss: 0.002364
# Epoch 161 - Training time: 4.9773 seconds, Validation time: 0.8495 seconds
# Epoch 162/200 - Train loss: 0.001712, Val loss: 0.002249
# Epoch 162 - Training time: 4.9500 seconds, Validation time: 0.8412 seconds
# Epoch 163/200 - Train loss: 0.001832, Val loss: 0.002139
# Epoch 163 - Training time: 4.8951 seconds, Validation time: 0.8442 seconds
# Epoch 164/200 - Train loss: 0.002191, Val loss: 0.002601
# Epoch 164 - Training time: 4.9681 seconds, Validation time: 0.8466 seconds
# Epoch 165/200 - Train loss: 0.002132, Val loss: 0.003293
# Epoch 165 - Training time: 4.9746 seconds, Validation time: 0.8462 seconds
# Epoch 166/200 - Train loss: 0.002163, Val loss: 0.002247
# Epoch 166 - Training time: 4.9608 seconds, Validation time: 0.8552 seconds
# Epoch 167/200 - Train loss: 0.002100, Val loss: 0.002163
# Epoch 167 - Training time: 4.9273 seconds, Validation time: 0.8393 seconds
# Epoch 168/200 - Train loss: 0.001837, Val loss: 0.002473
# Epoch 168 - Training time: 4.9512 seconds, Validation time: 0.8406 seconds
# Epoch 169/200 - Train loss: 0.001820, Val loss: 0.002154
# Epoch 169 - Training time: 4.9320 seconds, Validation time: 0.8402 seconds
# Epoch 170/200 - Train loss: 0.001744, Val loss: 0.002717
# Epoch 170 - Training time: 4.9527 seconds, Validation time: 0.8543 seconds
# Epoch 171/200 - Train loss: 0.001944, Val loss: 0.002129
# Epoch 171 - Training time: 4.9519 seconds, Validation time: 0.8442 seconds
# Epoch 172/200 - Train loss: 0.001984, Val loss: 0.002492
# Epoch 172 - Training time: 4.9762 seconds, Validation time: 0.8426 seconds
# Epoch 173/200 - Train loss: 0.002335, Val loss: 0.003502
# Epoch 173 - Training time: 4.9692 seconds, Validation time: 0.8492 seconds
# Epoch 174/200 - Train loss: 0.003309, Val loss: 0.005078
# Epoch 174 - Training time: 4.9514 seconds, Validation time: 0.8492 seconds
# Epoch 175/200 - Train loss: 0.003368, Val loss: 0.006009
# Epoch 175 - Training time: 4.9522 seconds, Validation time: 0.8486 seconds
# Epoch 176/200 - Train loss: 0.003904, Val loss: 0.002766
# Epoch 176 - Training time: 4.9756 seconds, Validation time: 0.8452 seconds
# Epoch 177/200 - Train loss: 0.002041, Val loss: 0.002000
# Epoch 177 - Training time: 4.9428 seconds, Validation time: 0.8432 seconds
# Epoch 178/200 - Train loss: 0.001620, Val loss: 0.002110
# Epoch 178 - Training time: 4.9585 seconds, Validation time: 0.8513 seconds
# Epoch 179/200 - Train loss: 0.001628, Val loss: 0.002047
# Epoch 179 - Training time: 5.0010 seconds, Validation time: 0.8432 seconds
# Epoch 180/200 - Train loss: 0.001696, Val loss: 0.002047
# Epoch 180 - Training time: 4.9884 seconds, Validation time: 0.8534 seconds
# Epoch 181/200 - Train loss: 0.001605, Val loss: 0.002185
# Epoch 181 - Training time: 4.9878 seconds, Validation time: 0.8502 seconds
# Epoch 182/200 - Train loss: 0.001670, Val loss: 0.002034
# Epoch 182 - Training time: 4.9886 seconds, Validation time: 0.8542 seconds
# Epoch 183/200 - Train loss: 0.001945, Val loss: 0.002349
# Epoch 183 - Training time: 4.9915 seconds, Validation time: 0.8538 seconds
# Epoch 184/200 - Train loss: 0.001866, Val loss: 0.002096
# Epoch 184 - Training time: 4.9899 seconds, Validation time: 0.8522 seconds
# Epoch 185/200 - Train loss: 0.001556, Val loss: 0.002063
# Epoch 185 - Training time: 4.9948 seconds, Validation time: 0.8532 seconds
# Epoch 186/200 - Train loss: 0.001636, Val loss: 0.002463
# Epoch 186 - Training time: 4.9649 seconds, Validation time: 0.8532 seconds
# Epoch 187/200 - Train loss: 0.002135, Val loss: 0.003105
# Epoch 187 - Training time: 4.9539 seconds, Validation time: 0.8474 seconds
# Epoch 188/200 - Train loss: 0.002182, Val loss: 0.002037
# Epoch 188 - Training time: 4.9846 seconds, Validation time: 0.8506 seconds
# Epoch 189/200 - Train loss: 0.001969, Val loss: 0.002701
# Epoch 189 - Training time: 4.9999 seconds, Validation time: 0.8487 seconds
# Epoch 190/200 - Train loss: 0.002110, Val loss: 0.002273
# Epoch 190 - Training time: 4.9867 seconds, Validation time: 0.8545 seconds
# Epoch 191/200 - Train loss: 0.001868, Val loss: 0.002174
# Epoch 191 - Training time: 4.9765 seconds, Validation time: 0.8539 seconds
# Epoch 192/200 - Train loss: 0.001802, Val loss: 0.002450
# Epoch 192 - Training time: 4.9783 seconds, Validation time: 0.8482 seconds
# Epoch 193/200 - Train loss: 0.001925, Val loss: 0.002679
# Epoch 193 - Training time: 4.9618 seconds, Validation time: 0.8502 seconds
# Epoch 194/200 - Train loss: 0.001916, Val loss: 0.002382
# Epoch 194 - Training time: 4.9481 seconds, Validation time: 0.8493 seconds
# Epoch 195/200 - Train loss: 0.001594, Val loss: 0.002066
# Epoch 195 - Training time: 4.9723 seconds, Validation time: 0.8440 seconds
# Epoch 196/200 - Train loss: 0.001557, Val loss: 0.002192
# Epoch 196 - Training time: 4.9578 seconds, Validation time: 0.8472 seconds
# Epoch 197/200 - Train loss: 0.001801, Val loss: 0.002060
# Epoch 197 - Training time: 4.9626 seconds, Validation time: 0.8552 seconds
# Epoch 198/200 - Train loss: 0.002043, Val loss: 0.002181
# Epoch 198 - Training time: 4.9738 seconds, Validation time: 0.8425 seconds
# Epoch 199/200 - Train loss: 0.001656, Val loss: 0.002166
# Epoch 199 - Training time: 5.0446 seconds, Validation time: 0.8452 seconds
# Epoch 200/200 - Train loss: 0.001755, Val loss: 0.002354
# Epoch 200 - Training time: 4.9661 seconds, Validation time: 0.8432 seconds
# Training time: 1170.3031 seconds

# %%
plt.figure()
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Train and Validation Loss per Epoch')
plt.savefig('train_val_loss_plot.png')
plt.show()

# %%
# unet.eval()
# test_loss = 0.0

# with torch.no_grad():
#     for rain, norain in test_loader:
#         rain = rain.to(device)
#         norain = norain.to(device)

#         with autocast():
#             output = unet(rain)
#             loss = criterion(output, norain)

#         test_loss += loss.item()

# print(f"Test loss: {test_loss/len(test_loader):.6f}")
# Out:
# Test loss: 0.003194

# %%
# Test the model and save derained images
print('--- Testing starts! ---')
start_time_test = time.time()

unet.eval()
test_psnr = 0.0
test_ssim = 0.0
output_path = "G:\My Drive\Deraining\Rain100L\derained"
if not os.path.exists(output_path):
    os.makedirs(output_path)
metrics = []
with torch.no_grad():
    img_count = 1
    for i, (rain, norain) in enumerate(test_loader):
        rain = rain.to(device)
        norain = norain.to(device)

        output = unet(rain)
        output = output.cpu().numpy().transpose((0, 2, 3, 1)).clip(0, 1)
        norain = norain.cpu().numpy().transpose((0, 2, 3, 1)).clip(0, 1)

        for j in range(output.shape[0]):
            # Save the derained image
            output_img = Image.fromarray((output[j] * 255).astype(np.uint8))
            output_img.save(os.path.join(output_path, f"derained_{img_count}.png"))

            # Compute PSNR and SSIM
            cur_psnr = psnr(norain[j], output[j], data_range=1)
            cur_ssim = ssim(norain[j], output[j], data_range=1, multichannel=True)

            metrics.append([cur_psnr, cur_ssim])
            img_count += 1

# Save the metrics to a CSV file and compute the average and standard deviation
metrics_df = pd.DataFrame(metrics, columns=["PSNR", "SSIM"])
metrics_df.to_csv("metrics.csv", index=False)

mean_psnr = metrics_df["PSNR"].mean()
mean_ssim = metrics_df["SSIM"].mean()
std_psnr = metrics_df["PSNR"].std()
std_ssim = metrics_df["SSIM"].std()

print(f"Average PSNR: {mean_psnr:.6f} (std: {std_psnr:.6f}), Average SSIM: {mean_ssim:.6f} (std: {std_ssim:.6f})")
# Out:
# --- Testing starts! ---
# C:\Users\labuser\AppData\Local\Temp\ipykernel_9544\1426726481.py:29: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   cur_ssim = ssim(norain[j], output[j], data_range=1, multichannel=True)
# Average PSNR: 28.002480 (std: 2.150920), Average SSIM: 0.874650 (std: 0.068148)
